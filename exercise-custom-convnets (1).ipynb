# %% [markdown]
# **This notebook is an exercise in the [Computer Vision](https://www.kaggle.com/learn/computer-vision) course.  You can reference the tutorial at [this link](https://www.kaggle.com/ryanholbrook/custom-convnets).**
#
# ---

# %% [markdown]
# # Introduction #
#
# In these exercises, you'll build a custom convnet with performance competitive to the VGG16 model from Lesson 1.
#
# Get started by running the code cell below.

# %%
# Setup feedback system
from learntools.core import binder
binder.bind(globals())
from learntools.computer_vision.ex5 import *

# Imports
import os, warnings
import matplotlib.pyplot as plt
from matplotlib import gridspec

import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing import image_dataset_from_directory

# Reproducability
def set_seed(seed=31415):
    np.random.seed(seed)
    tf.random.set_seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    os.environ['TF_DETERMINISTIC_OPS'] = '1'
set_seed()

# Set Matplotlib defaults
plt.rc('figure', autolayout=True)
plt.rc('axes', labelweight='bold', labelsize='large',
       titleweight='bold', titlesize=18, titlepad=10)
plt.rc('image', cmap='magma')
warnings.filterwarnings("ignore") # to clean up output cells


# Load training and validation sets
ds_train_ = image_dataset_from_directory(
    '../input/car-or-truck/train',
    labels='inferred',
    label_mode='binary',
    image_size=[128, 128],
    interpolation='nearest',
    batch_size=64,
    shuffle=True,
)
ds_valid_ = image_dataset_from_directory(
    '../input/car-or-truck/valid',
    labels='inferred',
    label_mode='binary',
    image_size=[128, 128],
    interpolation='nearest',
    batch_size=64,
    shuffle=False,
)

# Data Pipeline
def convert_to_float(image, label):
    image = tf.image.convert_image_dtype(image, dtype=tf.float32)
    return image, label

AUTOTUNE = tf.data.experimental.AUTOTUNE
ds_train = (
    ds_train_
    .map(convert_to_float)
    .cache()
    .prefetch(buffer_size=AUTOTUNE)
)
ds_valid = (
    ds_valid_
    .map(convert_to_float)
    .cache()
    .prefetch(buffer_size=AUTOTUNE)
)
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# Found 5117 files belonging to 2 classes.
# Found 5051 files belonging to 2 classes.

# %% [markdown]
# # Design a Convnet #
#
# Let's design a convolutional network with a block architecture like we saw in the tutorial. The model from the example had three blocks, each with a single convolutional layer. Its performance on the "Car or Truck" problem was okay, but far from what the pretrained VGG16 could achieve. It might be that our simple network lacks the ability to extract sufficiently complex features. We could try improving the model either by adding more blocks or by adding convolutions to the blocks we have.
#
# Let's go with the second approach. We'll keep the three block structure, but increase the number of `Conv2D` layer in the second block to two, and in the third block to three.
#
# <figure>
# <!-- <img src="./images/2-convmodel-2.png" width="250" alt="Diagram of a convolutional model."> -->
# <img src="https://storage.googleapis.com/kaggle-media/learn/images/Vko6nCK.png" width="250" alt="Diagram of a convolutional model.">
# </figure>
#
# # 1) Define Model #
#
# Given the diagram above, complete the model by defining the layers of the third block.

# %%
from tensorflow import keras
from tensorflow.keras import layers

model = keras.Sequential([
    # Block One
    layers.Conv2D(filters=32, kernel_size=3, activation='relu', padding='same',
                  input_shape=[128, 128, 3]),
    layers.MaxPool2D(),

    # Block Two
    layers.Conv2D(filters=64, kernel_size=3, activation='relu', padding='same'),
    layers.MaxPool2D(),

    # Block Three
    # YOUR CODE HERE
    layers.Conv2D(filters=128, kernel_size=3, activation='relu', padding='same'),
    layers.Conv2D(filters=128, kernel_size=3, activation='relu', padding='same'),
    layers.MaxPool2D(),

    # Head
    layers.Flatten(),
    layers.Dense(6, activation='relu'),
    layers.Dropout(0.2),
    layers.Dense(1, activation='sigmoid'),
])

# Check your answer
q_1.check()
# Out:
# Correct

# %%
# Lines below will give you a hint or solution code
#q_1.hint()
#q_1.solution()

# %% [markdown]
# # 2) Compile #
#
# To prepare for training, compile the model with an appropriate loss and accuracy metric for the "Car or Truck" dataset.

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(epsilon=0.01),
    loss='binary_crossentropy',
    metrics=['binary_accuracy'],
)

# Check your answer
q_2.check()
# Out:
# Correct

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(epsilon=0.01),
    loss='binary_crossentropy',
    metrics=['binary_accuracy'],
)
q_2.assert_check_passed()
# Out:
# Correct

# %%
# Lines below will give you a hint or solution code
#q_2.hint()
# q_2.solution()

# %% [markdown]
# Finally, let's test the performance of this new model. First run this cell to fit the model to the training set.

# %%
history = model.fit(
    ds_train,
    validation_data=ds_valid,
    epochs=50,
)
# Out:
# Epoch 1/50
# 80/80 [==============================] - 212s 3s/step - loss: 0.6849 - binary_accuracy: 0.5787 - val_loss: 0.6821 - val_binary_accuracy: 0.5785
# Epoch 2/50
# 80/80 [==============================] - 214s 3s/step - loss: 0.6810 - binary_accuracy: 0.5787 - val_loss: 0.6790 - val_binary_accuracy: 0.5785
# Epoch 3/50
# 80/80 [==============================] - 213s 3s/step - loss: 0.6777 - binary_accuracy: 0.5787 - val_loss: 0.6711 - val_binary_accuracy: 0.5785
# Epoch 4/50
# 80/80 [==============================] - 215s 3s/step - loss: 0.6680 - binary_accuracy: 0.5787 - val_loss: 0.6634 - val_binary_accuracy: 0.5785
# Epoch 5/50
# 80/80 [==============================] - 213s 3s/step - loss: 0.6668 - binary_accuracy: 0.5787 - val_loss: 0.6596 - val_binary_accuracy: 0.5785
# Epoch 6/50
# 80/80 [==============================] - 212s 3s/step - loss: 0.6627 - binary_accuracy: 0.5787 - val_loss: 0.6560 - val_binary_accuracy: 0.5785
# Epoch 7/50
# 80/80 [==============================] - 215s 3s/step - loss: 0.6613 - binary_accuracy: 0.5787 - val_loss: 0.6520 - val_binary_accuracy: 0.5785
# Epoch 8/50
# 80/80 [==============================] - 212s 3s/step - loss: 0.6550 - binary_accuracy: 0.5787 - val_loss: 0.6455 - val_binary_accuracy: 0.5785
# Epoch 9/50
# 80/80 [==============================] - 212s 3s/step - loss: 0.6529 - binary_accuracy: 0.5787 - val_loss: 0.6414 - val_binary_accuracy: 0.5785
# Epoch 10/50
# 80/80 [==============================] - 212s 3s/step - loss: 0.6482 - binary_accuracy: 0.5787 - val_loss: 0.6364 - val_binary_accuracy: 0.5785
# Epoch 11/50
# 80/80 [==============================] - 212s 3s/step - loss: 0.6424 - binary_accuracy: 0.5787 - val_loss: 0.6311 - val_binary_accuracy: 0.5785
# Epoch 12/50
# 80/80 [==============================] - 212s 3s/step - loss: 0.6407 - binary_accuracy: 0.5787 - val_loss: 0.6324 - val_binary_accuracy: 0.5785
# Epoch 13/50
# 80/80 [==============================] - 214s 3s/step - loss: 0.6376 - binary_accuracy: 0.5787 - val_loss: 0.6242 - val_binary_accuracy: 0.5783
# Epoch 14/50
# 80/80 [==============================] - 252s 3s/step - loss: 0.6373 - binary_accuracy: 0.6084 - val_loss: 0.6208 - val_binary_accuracy: 0.6561
# Epoch 15/50
# 80/80 [==============================] - 214s 3s/step - loss: 0.6367 - binary_accuracy: 0.6111 - val_loss: 0.6197 - val_binary_accuracy: 0.6518
# Epoch 16/50
# 80/80 [==============================] - 215s 3s/step - loss: 0.6315 - binary_accuracy: 0.6168 - val_loss: 0.6147 - val_binary_accuracy: 0.6620
# Epoch 17/50
# 80/80 [==============================] - 252s 3s/step - loss: 0.6316 - binary_accuracy: 0.6201 - val_loss: 0.6147 - val_binary_accuracy: 0.6595
# Epoch 18/50
# 80/80 [==============================] - 215s 3s/step - loss: 0.6273 - binary_accuracy: 0.6232 - val_loss: 0.6161 - val_binary_accuracy: 0.6579
# Epoch 19/50
# 80/80 [==============================] - 215s 3s/step - loss: 0.6239 - binary_accuracy: 0.6543 - val_loss: 0.6172 - val_binary_accuracy: 0.6634
# Epoch 20/50
# 80/80 [==============================] - 214s 3s/step - loss: 0.6102 - binary_accuracy: 0.6721 - val_loss: 0.6017 - val_binary_accuracy: 0.6779
# Epoch 21/50
# 80/80 [==============================] - 213s 3s/step - loss: 0.6049 - binary_accuracy: 0.6887 - val_loss: 0.5948 - val_binary_accuracy: 0.6870
# Epoch 22/50
# 80/80 [==============================] - 250s 3s/step - loss: 0.5933 - binary_accuracy: 0.6904 - val_loss: 0.5783 - val_binary_accuracy: 0.6955
# Epoch 23/50
# 80/80 [==============================] - 214s 3s/step - loss: 0.5775 - binary_accuracy: 0.7043 - val_loss: 0.5706 - val_binary_accuracy: 0.7044
# Epoch 24/50
# 80/80 [==============================] - 214s 3s/step - loss: 0.5630 - binary_accuracy: 0.7106 - val_loss: 0.5550 - val_binary_accuracy: 0.7115
# Epoch 25/50
# 80/80 [==============================] - 249s 3s/step - loss: 0.5511 - binary_accuracy: 0.7270 - val_loss: 0.5451 - val_binary_accuracy: 0.7218
# Epoch 26/50
# 80/80 [==============================] - 213s 3s/step - loss: 0.5275 - binary_accuracy: 0.7473 - val_loss: 0.5407 - val_binary_accuracy: 0.7193
# Epoch 27/50
# 80/80 [==============================] - 214s 3s/step - loss: 0.5033 - binary_accuracy: 0.7612 - val_loss: 0.4998 - val_binary_accuracy: 0.7597
# Epoch 28/50
# 80/80 [==============================] - 213s 3s/step - loss: 0.4843 - binary_accuracy: 0.7751 - val_loss: 0.4713 - val_binary_accuracy: 0.7725
# Epoch 29/50
# 80/80 [==============================] - 214s 3s/step - loss: 0.4495 - binary_accuracy: 0.7948 - val_loss: 0.4483 - val_binary_accuracy: 0.7911
# Epoch 30/50
# 80/80 [==============================] - 250s 3s/step - loss: 0.4291 - binary_accuracy: 0.8100 - val_loss: 0.4660 - val_binary_accuracy: 0.7735
# Epoch 31/50
# 80/80 [==============================] - 216s 3s/step - loss: 0.4006 - binary_accuracy: 0.8218 - val_loss: 0.4505 - val_binary_accuracy: 0.7878
# Epoch 32/50
# 80/80 [==============================] - 213s 3s/step - loss: 0.3793 - binary_accuracy: 0.8323 - val_loss: 0.4153 - val_binary_accuracy: 0.8089
# Epoch 33/50
# 80/80 [==============================] - 215s 3s/step - loss: 0.3521 - binary_accuracy: 0.8460 - val_loss: 0.4251 - val_binary_accuracy: 0.8030
# Epoch 34/50
# 80/80 [==============================] - 214s 3s/step - loss: 0.3289 - binary_accuracy: 0.8566 - val_loss: 0.4112 - val_binary_accuracy: 0.8181
# Epoch 35/50
# 80/80 [==============================] - 215s 3s/step - loss: 0.3048 - binary_accuracy: 0.8732 - val_loss: 0.4159 - val_binary_accuracy: 0.8232
# Epoch 36/50
# 80/80 [==============================] - 215s 3s/step - loss: 0.2848 - binary_accuracy: 0.8804 - val_loss: 0.4172 - val_binary_accuracy: 0.8127
# Epoch 37/50
# 80/80 [==============================] - 214s 3s/step - loss: 0.2534 - binary_accuracy: 0.8910 - val_loss: 0.4209 - val_binary_accuracy: 0.8369
# Epoch 38/50
# 80/80 [==============================] - 213s 3s/step - loss: 0.2575 - binary_accuracy: 0.8947 - val_loss: 0.4068 - val_binary_accuracy: 0.8252
# Epoch 39/50
# 80/80 [==============================] - 214s 3s/step - loss: 0.2246 - binary_accuracy: 0.9040 - val_loss: 0.4614 - val_binary_accuracy: 0.8072
# Epoch 40/50
# 80/80 [==============================] - 215s 3s/step - loss: 0.2016 - binary_accuracy: 0.9187 - val_loss: 0.4641 - val_binary_accuracy: 0.8173
# Epoch 41/50
# 80/80 [==============================] - 215s 3s/step - loss: 0.1879 - binary_accuracy: 0.9226 - val_loss: 0.5175 - val_binary_accuracy: 0.7996
# Epoch 42/50
# 80/80 [==============================] - 216s 3s/step - loss: 0.2023 - binary_accuracy: 0.9162 - val_loss: 0.5482 - val_binary_accuracy: 0.8076
# Epoch 43/50
# 80/80 [==============================] - 216s 3s/step - loss: 0.1593 - binary_accuracy: 0.9320 - val_loss: 0.5994 - val_binary_accuracy: 0.7947
# Epoch 44/50
# 80/80 [==============================] - 216s 3s/step - loss: 0.1692 - binary_accuracy: 0.9269 - val_loss: 0.4839 - val_binary_accuracy: 0.8208
# Epoch 45/50
# 80/80 [==============================] - 215s 3s/step - loss: 0.1716 - binary_accuracy: 0.9308 - val_loss: 0.4251 - val_binary_accuracy: 0.8483
# Epoch 46/50
# 80/80 [==============================] - 214s 3s/step - loss: 0.1914 - binary_accuracy: 0.9130 - val_loss: 0.4481 - val_binary_accuracy: 0.8418
# Epoch 47/50
# 80/80 [==============================] - 214s 3s/step - loss: 0.1734 - binary_accuracy: 0.9244 - val_loss: 0.4815 - val_binary_accuracy: 0.8509
# Epoch 48/50
# 80/80 [==============================] - 217s 3s/step - loss: 0.1382 - binary_accuracy: 0.9453 - val_loss: 0.5149 - val_binary_accuracy: 0.8472
# Epoch 49/50
# 80/80 [==============================] - 214s 3s/step - loss: 0.1384 - binary_accuracy: 0.9427 - val_loss: 0.5414 - val_binary_accuracy: 0.8349
# Epoch 50/50
# 80/80 [==============================] - 251s 3s/step - loss: 0.1212 - binary_accuracy: 0.9517 - val_loss: 0.6434 - val_binary_accuracy: 0.8375

# %% [markdown]
# And now run the cell below to plot the loss and metric curves for this training run.

# %%
import pandas as pd
history_frame = pd.DataFrame(history.history)
history_frame.loc[:, ['loss', 'val_loss']].plot()
history_frame.loc[:, ['binary_accuracy', 'val_binary_accuracy']].plot();

# %% [markdown]
# # 3) Train the Model #
#
# How would you interpret these training curves? Did this model improve upon the model from the tutorial?

# %%
# View the solution (Run this code cell to receive credit!)
q_3.check()
# Out:
# Correct:
#
#
# The learning curves for the model from the tutorial diverged fairly rapidly. This would indicate that it was prone to overfitting and in need of some regularization. The additional layer in our new model would make it even more prone to overfitting. However, adding some regularization with the `Dropout` layer helped prevent this. These changes improved the validation accuracy of the model by several points.

# %% [markdown]
# # Conclusion #
#
# These exercises showed you how to design a custom convolutional network to solve a specific classification problem. Though most models these days will be built on top of a pretrained base, it certain circumstances a smaller custom convnet might still be preferable -- such as with a smaller or unusual dataset or when computing resources are very limited. As you saw here, for certain problems they can perform just as well as a pretrained model.
#
# # Keep Going #
#
# Continue on to [**Lesson 6**](https://www.kaggle.com/ryanholbrook/data-augmentation), where you'll learn a widely-used technique that can give a boost to your training data: **data augmentation**.

# %% [markdown]
# ---
#
#
#
#
# *Have questions or comments? Visit the [course discussion forum](https://www.kaggle.com/learn/computer-vision/discussion) to chat with other learners.*
